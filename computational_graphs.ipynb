# %%
# %load_ext autoreload
# %autoreload 2

# %%
import compgraph as cg
import matplotlib.pyplot as plt

import networkx as nx

# %%
p = cg.Variable("p")
q = cg.Variable("q")
expression = p + p + q
expression.graph()
