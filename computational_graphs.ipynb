# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import compgraph as cg
import matplotlib.pyplot as plt

import networkx as nx

# %%
p = cg.Variable("p")
q = cg.Variable("q")
expression = cg.sqrt(p + p + q) + cg.ln(p * (p * q))
expression.graph()
